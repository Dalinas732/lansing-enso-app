# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df_full = pd.read_csv("data/full_data_encoded.csv", low_memory=False)
df_full
# Out:
#      index  Unnamed: 0        Date  Year Month  Global Temperature Anomalies  \
# 0      120         120  1960-01-01  1960   JAN                          0.04
# 1      121         121  1960-02-01  1960   FEB                          0.15
# 2      122         122  1960-03-01  1960   MAR                         -0.24
# 3      123         123  1960-04-01  1960   APR                         -0.11
# 4      124         124  1960-05-01  1960   MAY                         -0.07
# ..     ...         ...         ...   ...   ...                           ...
# 775    895         895  2024-08-01  2024   AUG                          1.27
# 776    896         896  2024-09-01  2024   SEP                          1.25
# 777    897         897  2024-10-01  2024   OCT                          1.33
# 778    898         898  2024-11-01  2024   NOV                          1.32
# 779    899         899  2024-12-01  2024   DEC                          1.29
#
# ...

# %%
missing = df_full["Global Precipitation"].isna().sum()
print(missing)
# Out:
# 228

# %%
228/12
# Out:
# 19.0

# %%
df_full.iloc[0:302,:]
# Out:
#      index  Unnamed: 0        Date  Year Month  Global Temperature Anomalies  \
# 0      120         120  1960-01-01  1960   JAN                          0.04
# 1      121         121  1960-02-01  1960   FEB                          0.15
# 2      122         122  1960-03-01  1960   MAR                         -0.24
# 3      123         123  1960-04-01  1960   APR                         -0.11
# 4      124         124  1960-05-01  1960   MAY                         -0.07
# ..     ...         ...         ...   ...   ...                           ...
# 297    417         417  1984-10-01  1984   OCT                          0.17
# 298    418         418  1984-11-01  1984   NOV                          0.08
# 299    419         419  1984-12-01  1984   DEC                          0.02
# 300    420         420  1985-01-01  1985   JAN                          0.27
# 301    421         421  1985-02-01  1985   FEB                          0.04
#
# ...
